# %% [markdown]
# <a href="https://colab.research.google.com/github/IFBbot1/Wind_Diplom/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://github.com/lgpedersen/hwm14.git
# Out:
# Collecting git+https://github.com/lgpedersen/hwm14.git
#   Cloning https://github.com/lgpedersen/hwm14.git to /tmp/pip-req-build-8at1cv52
#   Running command git clone --filter=blob:none --quiet https://github.com/lgpedersen/hwm14.git /tmp/pip-req-build-8at1cv52
#   Resolved https://github.com/lgpedersen/hwm14.git to commit eaa2af228c084f4f77aacc9896519108e5bdf6f2
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.11/dist-packages (from hwm14==0.9.1) (2.8.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from hwm14==0.9.1) (2.0.2)
# Requirement already satisfied: xarray in /usr/local/lib/python3.11/dist-packages (from hwm14==0.9.1) (2025.1.2)
# Collecting sciencedates (from hwm14==0.9.1)
#   Downloading sciencedates-1.5.0.tar.gz (7.2 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil->hwm14==0.9.1) (1.17.0)
# Requirement already satisfied: packaging>=23.2 in /usr/local/lib/python3.11/dist-packages (from xarray->hwm14==0.9.1) (24.2)
# Requirement already satisfied: pandas>=2.1 in /usr/local/lib/python3.11/dist-packages (from xarray->hwm14==0.9.1) (2.2.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.1->xarray->hwm14==0.9.1) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.1->xarray->hwm14==0.9.1) (2025.1)
# Building wheels for collected packages: hwm14, sciencedates
#   Building wheel for hwm14 (pyproject.toml) ... done
#   Created wheel for hwm14: filename=hwm14-0.9.1-cp311-cp311-linux_x86_64.whl size=350636 sha256=49c8dfd40ae0fefb50232e3cb240f8daa1a476e6625eb34bb6953382e6953777
#   Stored in directory: /tmp/pip-ephem-wheel-cache-60cuii2a/wheels/cf/db/7a/c14869a425ab1a0b3e3fa3c463bc45d3a7f2ac7bb237720eed
#   Building wheel for sciencedates (pyproject.toml) ... done
#   Created wheel for sciencedates: filename=sciencedates-1.5.0-py3-none-any.whl size=9902 sha256=e8bb5b1738b657b8af02f21bd55444b0392bba7e9932c079feed3e8578cb1c2a
#   Stored in directory: /root/.cache/pip/wheels/98/b0/a0/848d6a06116a260fc1935ab19d7054b540f1deb06de6207bca
# Successfully built hwm14 sciencedates
# Installing collected packages: sciencedates, hwm14
# Successfully installed hwm14-0.9.1 sciencedates-1.5.0

# %%
import hwm14
from hwm14 import plots

import datetime as dt

# %%
# при вызове задается:
#    дата - как объект dt.datetime
#    altkm: набор высот (в километрах)
#    широта (в градусах северной широты)
#    долгота (в градусах восточной долготы)
#    индекс 107 средний за 90 дней
#    индекс f107 текущий
#    индекс ap
winds = hwm14.run(dt.datetime(2017, 11, 12, 8), altkm=range(100, 1265, 5), glat=52., glon=104., f107a=150, f107=150, ap=4)

# %%
winds
# Out:
# <xarray.Dataset> Size: 6kB
# Dimensions:     (alt_km: 233)
# Coordinates:
#   * alt_km      (alt_km) float64 2kB 100.0 105.0 110.0 ... 1.255e+03 1.26e+03
# Data variables:
#     meridional  (alt_km) float64 2kB 34.71 32.48 17.69 ... 46.62 46.62 46.62
#     zonal       (alt_km) float64 2kB 12.92 33.98 46.03 ... 48.28 48.28 48.28
# Attributes:
#     time:     2017-11-12T08:00:00
#     glat:     52.0
#     glon:     104.0

# %%
hwm14.plots.plothwm(winds)

# %%
# можно преобразовать в датафрейм pandas
import pandas as pd
df = winds.to_dataframe()

# %%
df
# Out:
#         meridional      zonal
# alt_km
# 100.0    34.708679  12.919756
# 105.0    32.481190  33.978798
# 110.0    17.685165  46.034882
# 115.0    11.833110  62.287449
# 120.0     8.118735  69.264488
# ...            ...        ...
# 1240.0   46.622826  48.284218
# 1245.0   46.622826  48.284218
# 1250.0   46.622826  48.284218
# 1255.0   46.622826  48.284218
# 1260.0   46.622826  48.284218
#
# [233 rows x 2 columns]

# %%
df.plot(grid=True)
# Out:
# <Axes: xlabel='alt_km'>
